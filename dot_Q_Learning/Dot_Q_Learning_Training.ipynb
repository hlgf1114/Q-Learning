# %%
# !pip install pygame
# Out:
# Collecting pygame
#   Downloading https://files.pythonhosted.org/packages/8e/24/ede6428359f913ed9cd1643dd5533aefeb5a2699cc95bea089de50ead586/pygame-1.9.6-cp36-cp36m-manylinux1_x86_64.whl (11.4MB)
#      |████████████████████████████████| 11.4MB 2.7MB/s
# Installing collected packages: pygame
# Successfully installed pygame-1.9.6

# %%
from google.colab import drive
import sys

# google colab은 화면이 없으므로 가상으로 하나 만든다.
import os
os.environ['SDL_VIDEODRIVER']='dummy'
import pygame
pygame.display.set_mode((640,480))

# Q_table을 직렬화해서 저장하기 위한 묘듈
import pickle

drive.mount('/content/gdrive')
# Out:
# pygame 1.9.6
# Hello from the pygame community. https://www.pygame.org/contribute.html
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3aietf%3awg%3aoauth%3a2.0%3aoob&response_type=code&scope=email%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdocs.test%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive.photos.readonly%20https%3a%2f%2fwww.googleapis.com%2fauth%2fpeopleapi.readonly
#
# Enter your authorization code:
# ··········
# Mounted at /content/gdrive

# %%
# 진행 상황 로그를 주기적으로 지워주기 위해
from IPython.display import clear_output

# %%
# !ls gdrive/My\ Drive/Colab\ Notebooks/py

sys.path.insert(0, '/content/gdrive/My Drive/Colab Notebooks/py/')
# Out:
# dot_Q.py  __pycache__

# %%
# 필요한 모듈 불러오기
import sys
import numpy as np
import random

#import pygame
import matplotlib.pyplot as plt
import datetime
import time

# 게임 불러오기
#import pong
import dot_Q as game

# %%
# 클래스 만들기
class Q_Learning:
    def __init__(self):
        # 게임 정보
        self.algorithm = 'Q_Learning'
        self.game_name = game.ReturnName()

        # 파라미터를 가져온다
        self.progress = ''
        self.num_action = game.Return_Num_Action()

        # 초기 파라미터
        self.num_training = 100000  # 트레이닝 step의 수 (Epsilon Greedy)
        self.num_testing = 1000  # 테스팅 step 수 (Epsilon = 0)

        self.learning_rate = 0.01  # 학습률
        self.gamma = 0.3  # Discount Factor 미래의 보상을 얼마나 고려할 것인지?

        self.first_epsilon = 1.0  # 처음의 epsilon의 값
        self.final_epsilon = 0.1  # 마지막 epsilon의 값

        self.epsilon = self.first_epsilon

        # 200 판마다 평균 점수를 plotting 할 지 결정
        self.num_plot_episode = 200

        self.step = 1  # 1번 action을 선택하고 행동
        self.score = 0  # 게임의 점수 (한 에피소드 안에서의 보상의 총 합)
        self.episode = 1  # 게임을 몇 판을 진행했는지 나타내는 수

        # plotting을 위한 데이터 저장
        self.plot_x = []
        self.plot_y = []

        self.date_time = str(datetime.date.today()) + '-' + str(datetime.datetime.now().hour) + '-' + str(
            datetime.datetime.now().minute)

        # Q-table 초기화
        self.Q_table = {} # Dictionary key: state, value: Q-value

        # 필요한 함수 정의

    def get_progress(self):
        progress = ''

        if self.step <= self.num_training:  # step이 정해놓은 학습 step의 수보다 작은 경우
            progress = 'Training'
        # 트레이닝 step 보다 크고 테스팅 step 보다 작을 경우 = testing
        elif self.step <= self.num_training + self.num_testing:
            progress = 'Testing'
        else:
            progress = "Finished"

        return progress

    def select_action(self, state):
        action = np.zeros([self.num_action])
        action_index = 0

        # 액션 선택
        if self.progress == 'Training':
            if random.random() < self.epsilon or state not in self.Q_table.keys():

                # 랜덤 액션 취함
                action_index = random.randint(0, self.num_action - 1)
                action[action_index] = 1
            else:
                # greedy 액션 취함
                action_index = np.argmax(self.Q_table[state])
                action[action_index] = 1

            # epsilon을 줄이면서 탐색을 줄인다.
            # epsilon의 최솟값은 0.1
            if self.epsilon > self.final_epsilon:
                self.epsilon -= self.first_epsilon / self.num_training

        elif self.progress == 'Testing':
            # greedy 액션을 취함
            action_index = np.argmax(self.Q_table[state])
            action[action_index] = 1

            # 탐색 종료
            self.epsilon = 0

        return action

    def train(self, state, action, reward, next_state, terminal):

        # state나 next_state가 Q_table에 없는 경우
        # 해당 state나 next state에 각각 action 에 대한 Q_value 추가
        # (0으로 초기화)

        if state not in self.Q_table.keys():
            self.Q_table[state] = []
            for i in range(self.num_action):
                self.Q_table[state].append(0)

        if next_state not in self.Q_table.keys():
            self.Q_table[next_state] = []
            for i in range(self.num_action):
                self.Q_table[next_state].append(0)

        # Q 값을 업데이트
        action_index = np.argmax(action)

        if state in self.Q_table.keys() and next_state in self.Q_table.keys():
            if terminal is True:
                # Q-Learning
                # terminal이 True 이면 // 즉 게임이 멈추면
                # Q-value = (1 - a) * Q-value + a * (reward)
                self.Q_table[state][action_index] = (1 - self.learning_rate) * self.Q_table[state][action_index] + self.learning_rate * (reward)
            else:
                # terminal이 False 이면 // 즉 게임이 진행되는 경우
                # Q-value = (1 - a) * Q-value + a * (reward + r*MaxQ)
                self.Q_table[state][action_index] = (1 - self.learning_rate) * self.learning_rate * self.Q_table[state][action_index] + (reward + self.gamma * max(self.Q_table[next_state]))

    def plotting(self):

        if len(self.plot_x) % self.num_plot_episode == 0 and len(self.plot_x) != 0:
            plt.xlabel('Episode')
            plt.ylabel('Score')
            plt.title(self.algorithm)
            plt.grid(True)

            # x축 데이터 = episode, y축 데이터 = 1 episode 동안의 reward의 합
            plt.plot(np.average(self.plot_x), np.average(self.plot_y), marker='*', ms=5)
            plt.draw()
            plt.pause(0.000001)

            self.plot_x = []
            self.plot_y = []

    def if_terminal(self, game_state):

        # 진행상황 표기
        print('Step: ' + str(self.step) + ' / ' + \
              'Episode: ' + str(self.episode) + ' / ' + \
              'Progress: ' + self.progress + ' / ' + \
              'Epsilon: ' + str(self.epsilon) + ' / ' + \
              'Score: ' + str(self.score))

        # 한 episode 가 끝날 때 episode와 score를 저장 (plot)
        # Episode 1 증가, 한 episode 동안의 Score 초기화
        self.plot_x.append(self.episode)
        self.plot_y.append(self.score)
        self.episode += 1
        self.score = 0

        # state 초기화
        state, _, _ = game_state.frame_step(np.zeros([self.num_action]))

        return state

    def main(self):

        # 게임 환경 초기화
        game_state = game.GameState()
        print(game_state)

        # 초기화
        action = np.zeros([self.num_action])
        state, _, _ = game_state.frame_step(action)

        print("state", state)

        while True:
            self.progress = self.get_progress()

            # 액션을 취한다. 0, 1, 2, 3
            action = self.select_action(state)

            # 액션을 취한 값을 환경에 대입
            next_state, reward, terminal = game_state.frame_step(action)

            # 트레이닝
            self.train(state, action, reward, next_state, terminal)

            # plotting, 쓰고 싶지 않다면 주석처리
            #self.plotting()

            # 프로그램이 끝나면
            if self.progress == 'Finished':
                print('Finished')
                break

            # info를 업데이트
            state = next_state
            self.score += reward
            self.step += 1

            if self.step % 10000 is 0:
              clear_output()

            if terminal:
                state = self.if_terminal(game_state)

        # 트레이닝과 테스팅을 끝내면 Q_table을 저장
        # 저장된 Q_table은 구글 드라이브에서 확인 가능
        with open('gdrive/My Drive/Colab Notebooks/dot_Q_table.pickle', 'wb') as file:
          pickle.dump(self.Q_table, file, pickle.HIGHEST_PROTOCOL)
          print("Q_table 저장 완료!")


if __name__ == '__main__':
    # 클래스 생성
    agent = Q_Learning()

    # 실행
    agent.main()
# Out:
# Step: 100000 / Episode: 18511 / Progress: Training / Epsilon: 0.09999000000191018 / Score: 0.96
# Step: 100001 / Episode: 18512 / Progress: Training / Epsilon: 0.09999000000191018 / Score: 1
# Step: 100004 / Episode: 18513 / Progress: Testing / Epsilon: 0 / Score: 0.98
# Step: 100005 / Episode: 18514 / Progress: Testing / Epsilon: 0 / Score: 1
# Step: 100006 / Episode: 18515 / Progress: Testing / Epsilon: 0 / Score: 1
# Step: 100008 / Episode: 18516 / Progress: Testing / Epsilon: 0 / Score: 0.99
# Step: 100012 / Episode: 18517 / Progress: Testing / Epsilon: 0 / Score: 0.97
# Step: 100017 / Episode: 18518 / Progress: Testing / Epsilon: 0 / Score: 0.96
# Step: 100022 / Episode: 18519 / Progress: Testing / Epsilon: 0 / Score: 0.96
# Step: 100025 / Episode: 18520 / Progress: Testing / Epsilon: 0 / Score: 0.98
# Step: 100028 / Episode: 18521 / Progress: Testing / Epsilon: 0 / Score: 0.98
# Step: 100031 / Episode: 18522 / Progress: Testing / Epsilon: 0 / Score: 0.98
# Step: 100034 / Episode: 18523 / Progress: Testing / Epsilon: 0 / Score: 0.98
# Step: 100035 / Episode: 18524 / Progress: Testing / Epsilon: 0 / Score: 1
# Step: 100036 / Episode: 18525 / Progress: Testing / Epsilon: 0 / Score: 1
# Step: 100040 / Episode: 18526 / Progress: Testing / Epsilon: 0 / Score: 0.97
# Step: 100043 / Episode: 18527 / Progress: Testing / Epsilon: 0 / Score: 0.98
# Step: 100046 / Episode: 18528 / Progress: Testing / Epsilon: 0 / Score: 0.98
# Step: 100049 / Episode: 18529 / Progress: Testing / Epsilon: 0 / Score: 0.98
# Step: 100050 / Episode: 18530 / Progress: Testing / Epsilon: 0 / Score: 1
# Step: 100055 / Episode: 18531 / Progress: Testing / Epsilon: 0 / Score: 0.96
# Step: 100058 / Episode: 18532 / Progress: Testing / Epsilon: 0 / Score: 0.98
# Step: 100062 / Episode: 18533 / Progress: Testing / Epsilon: 0 / Score: 0.97
# Step: 100063 / Episode: 18534 / Progress: Testing / Epsilon: 0 / Score: 1
# Step: 100064 / Episode: 18535 / Progress: Testing / Epsilon: 0 / Score: 1
# Step: 100066 / Episode: 18536 / Progress: Testing / Epsilon: 0 / Score: 0.99
# Step: 100072 / Episode: 18537 / Progress: Testing / Epsilon: 0 / Score: 0.95
# Step: 100074 / Episode: 18538 / Progress: Testing / Epsilon: 0 / Score: 0.99
# Step: 100077 / Episode: 18539 / Progress: Testing / Epsilon: 0 / Score: 0.98
# Step: 100080 / Episode: 18540 / Progress: Testing / Epsilon: 0 / Score: 0.98
# Step: 100083 / Episode: 18541 / Progress: Testing / Epsilon: 0 / Score: 0.98
# Step: 100086 / Episode: 18542 / Progress: Testing / Epsilon: 0 / Score: 0.98
# Step: 100090 / Episode: 18543 / Progress: Testing / Epsilon: 0 / Score: 0.97
# Step: 100092 / Episode: 18544 / Progress: Testing / Epsilon: 0 / Score: 0.99
# Step: 100096 / Episode: 18545 / Progress: Testing / Epsilon: 0 / Score: 0.97
# Step: 100098 / Episode: 18546 / Progress: Testing / Epsilon: 0 / Score: 0.99
# Step: 100100 / Episode: 18547 / Progress: Testing / Epsilon: 0 / Score: 0.99
# Step: 100101 / Episode: 18548 / Progress: Testing / Epsilon: 0 / Score: 1
# Step: 100103 / Episode: 18549 / Progress: Testing / Epsilon: 0 / Score: 0.99
# Step: 100106 / Episode: 18550 / Progress: Testing / Epsilon: 0 / Score: 0.98
# Step: 100107 / Episode: 18551 / Progress: Testing / Epsilon: 0 / Score: 1
# Step: 100109 / Episode: 18552 / Progress: Testing / Epsilon: 0 / Score: 0.99
# Step: 100112 / Episode: 18553 / Progress: Testing / Epsilon: 0 / Score: 0.98
# Step: 100113 / Episode: 18554 / Progress: Testing / Epsilon: 0 / Score: 1
# Step: 100115 / Episode: 18555 / Progress: Testing / Epsilon: 0 / Score: 0.99
# Step: 100117 / Episode: 18556 / Progress: Testing / Epsilon: 0 / Score: 0.99
# Step: 100119 / Episode: 18557 / Progress: Testing / Epsilon: 0 / Score: 0.99
# Step: 100121 / Episode: 18558 / Progress: Testing / Epsilon: 0 / Score: 0.99
# Step: 100124 / Episode: 18559 / Progress: Testing / Epsilon: 0 / Score: 0.98
# Step: 100125 / Episode: 18560 / Progress: Testing / Epsilon: 0 / Score: 1
# Step: 100127 / Episode: 18561 / Progress: Testing / Epsilon: 0 / Score: 0.99
# Step: 100129 / Episode: 18562 / Progress: Testing / Epsilon: 0 / Score: 0.99
# Step: 100130 / Episode: 18563 / Progress: Testing / Epsilon: 0 / Score: 1
# Step: 100132 / Episode: 18564 / Progress: Testing / Epsilon: 0 / Score: 0.99
# Step: 100135 / Episode: 18565 / Progress: Testing / Epsilon: 0 / Score: 0.98
# Step: 100138 / Episode: 18566 / Progress: Testing / Epsilon: 0 / Score: 0.98
# Step: 100139 / Episode: 18567 / Progress: Testing / Epsilon: 0 / Score: 1
# Step: 100142 / Episode: 18568 / Progress: Testing / Epsilon: 0 / Score: 0.98
# Step: 100144 / Episode: 18569 / Progress: Testing / Epsilon: 0 / Score: 0.99
# Step: 100148 / Episode: 18570 / Progress: Testing / Epsilon: 0 / Score: 0.97
# Step: 100149 / Episode: 18571 / Progress: Testing / Epsilon: 0 / Score: 1
# Step: 100152 / Episode: 18572 / Progress: Testing / Epsilon: 0 / Score: 0.98
# Step: 100154 / Episode: 18573 / Progress: Testing / Epsilon: 0 / Score: 0.99
# Step: 100156 / Episode: 18574 / Progress: Testing / Epsilon: 0 / Score: 0.99
# Step: 100158 / Episode: 18575 / Progress: Testing / Epsilon: 0 / Score: 0.99
# Step: 100160 / Episode: 18576 / Progress: Testing / Epsilon: 0 / Score: 0.99
# Step: 100164 / Episode: 18577 / Progress: Testing / Epsilon: 0 / Score: 0.97
# Step: 100168 / Episode: 18578 / Progress: Testing / Epsilon: 0 / Score: 0.97
# Step: 100173 / Episode: 18579 / Progress: Testing / Epsilon: 0 / Score: 0.96
# Step: 100175 / Episode: 18580 / Progress: Testing / Epsilon: 0 / Score: 0.99
# Step: 100177 / Episode: 18581 / Progress: Testing / Epsilon: 0 / Score: 0.99
# Step: 100181 / Episode: 18582 / Progress: Testing / Epsilon: 0 / Score: 0.97
# Step: 100182 / Episode: 18583 / Progress: Testing / Epsilon: 0 / Score: 1
# Step: 100186 / Episode: 18584 / Progress: Testing / Epsilon: 0 / Score: 0.97
# Step: 100190 / Episode: 18585 / Progress: Testing / Epsilon: 0 / Score: 0.97
# Step: 100192 / Episode: 18586 / Progress: Testing / Epsilon: 0 / Score: 0.99
# Step: 100194 / Episode: 18587 / Progress: Testing / Epsilon: 0 / Score: 0.99
# Step: 100197 / Episode: 18588 / Progress: Testing / Epsilon: 0 / Score: 0.98
# Step: 100199 / Episode: 18589 / Progress: Testing / Epsilon: 0 / Score: 0.99
# Step: 100201 / Episode: 18590 / Progress: Testing / Epsilon: 0 / Score: 0.99
# Step: 100205 / Episode: 18591 / Progress: Testing / Epsilon: 0 / Score: 0.97
# Step: 100208 / Episode: 18592 / Progress: Testing / Epsilon: 0 / Score: 0.98
# Step: 100211 / Episode: 18593 / Progress: Testing / Epsilon: 0 / Score: 0.98
# Step: 100214 / Episode: 18594 / Progress: Testing / Epsilon: 0 / Score: 0.98
# Step: 100217 / Episode: 18595 / Progress: Testing / Epsilon: 0 / Score: 0.98
# Step: 100219 / Episode: 18596 / Progress: Testing / Epsilon: 0 / Score: 0.99
# Step: 100221 / Episode: 18597 / Progress: Testing / Epsilon: 0 / Score: 0.99
# Step: 100223 / Episode: 18598 / Progress: Testing / Epsilon: 0 / Score: 0.99
# Step: 100225 / Episode: 18599 / Progress: Testing / Epsilon: 0 / Score: 0.99
# Step: 100228 / Episode: 18600 / Progress: Testing / Epsilon: 0 / Score: 0.98
# Step: 100231 / Episode: 18601 / Progress: Testing / Epsilon: 0 / Score: 0.98
# Step: 100234 / Episode: 18602 / Progress: Testing / Epsilon: 0 / Score: 0.98
# Step: 100236 / Episode: 18603 / Progress: Testing / Epsilon: 0 / Score: 0.99
# Step: 100238 / Episode: 18604 / Progress: Testing / Epsilon: 0 / Score: 0.99
# Step: 100239 / Episode: 18605 / Progress: Testing / Epsilon: 0 / Score: 1
# Step: 100243 / Episode: 18606 / Progress: Testing / Epsilon: 0 / Score: 0.97
# Step: 100244 / Episode: 18607 / Progress: Testing / Epsilon: 0 / Score: 1
# Step: 100246 / Episode: 18608 / Progress: Testing / Epsilon: 0 / Score: 0.99
# Step: 100250 / Episode: 18609 / Progress: Testing / Epsilon: 0 / Score: 0.97
# Step: 100252 / Episode: 18610 / Progress: Testing / Epsilon: 0 / Score: 0.99
# Step: 100255 / Episode: 18611 / Progress: Testing / Epsilon: 0 / Score: 0.98
# Step: 100256 / Episode: 18612 / Progress: Testing / Epsilon: 0 / Score: 1
# Step: 100258 / Episode: 18613 / Progress: Testing / Epsilon: 0 / Score: 0.99
# Step: 100259 / Episode: 18614 / Progress: Testing / Epsilon: 0 / Score: 1
# Step: 100262 / Episode: 18615 / Progress: Testing / Epsilon: 0 / Score: 0.98
# Step: 100264 / Episode: 18616 / Progress: Testing / Epsilon: 0 / Score: 0.99
# Step: 100268 / Episode: 18617 / Progress: Testing / Epsilon: 0 / Score: 0.97
# Step: 100274 / Episode: 18618 / Progress: Testing / Epsilon: 0 / Score: 0.95
# Step: 100276 / Episode: 18619 / Progress: Testing / Epsilon: 0 / Score: 0.99
# Step: 100277 / Episode: 18620 / Progress: Testing / Epsilon: 0 / Score: 1
# Step: 100281 / Episode: 18621 / Progress: Testing / Epsilon: 0 / Score: 0.97
# Step: 100283 / Episode: 18622 / Progress: Testing / Epsilon: 0 / Score: 0.99
# Step: 100284 / Episode: 18623 / Progress: Testing / Epsilon: 0 / Score: 1
# Step: 100285 / Episode: 18624 / Progress: Testing / Epsilon: 0 / Score: 1
# Step: 100286 / Episode: 18625 / Progress: Testing / Epsilon: 0 / Score: 1
# Step: 100290 / Episode: 18626 / Progress: Testing / Epsilon: 0 / Score: 0.97
# Step: 100292 / Episode: 18627 / Progress: Testing / Epsilon: 0 / Score: 0.99
# Step: 100294 / Episode: 18628 / Progress: Testing / Epsilon: 0 / Score: 0.99
# Step: 100296 / Episode: 18629 / Progress: Testing / Epsilon: 0 / Score: 0.99
# Step: 100297 / Episode: 18630 / Progress: Testing / Epsilon: 0 / Score: 1
# Step: 100300 / Episode: 18631 / Progress: Testing / Epsilon: 0 / Score: 0.98
# Step: 100302 / Episode: 18632 / Progress: Testing / Epsilon: 0 / Score: 0.99
# Step: 100303 / Episode: 18633 / Progress: Testing / Epsilon: 0 / Score: 1
# Step: 100305 / Episode: 18634 / Progress: Testing / Epsilon: 0 / Score: 0.99
# Step: 100310 / Episode: 18635 / Progress: Testing / Epsilon: 0 / Score: 0.96
# Step: 100312 / Episode: 18636 / Progress: Testing / Epsilon: 0 / Score: 0.99
# Step: 100315 / Episode: 18637 / Progress: Testing / Epsilon: 0 / Score: 0.98
# Step: 100319 / Episode: 18638 / Progress: Testing / Epsilon: 0 / Score: 0.97
# Step: 100322 / Episode: 18639 / Progress: Testing / Epsilon: 0 / Score: 0.98
# Step: 100325 / Episode: 18640 / Progress: Testing / Epsilon: 0 / Score: 0.98
# Step: 100329 / Episode: 18641 / Progress: Testing / Epsilon: 0 / Score: 0.97
# Step: 100332 / Episode: 18642 / Progress: Testing / Epsilon: 0 / Score: 0.98
# Step: 100336 / Episode: 18643 / Progress: Testing / Epsilon: 0 / Score: 0.97
# Step: 100339 / Episode: 18644 / Progress: Testing / Epsilon: 0 / Score: 0.98
# Step: 100342 / Episode: 18645 / Progress: Testing / Epsilon: 0 / Score: 0.98
# Step: 100345 / Episode: 18646 / Progress: Testing / Epsilon: 0 / Score: 0.98
# Step: 100349 / Episode: 18647 / Progress: Testing / Epsilon: 0 / Score: 0.97
# Step: 100352 / Episode: 18648 / Progress: Testing / Epsilon: 0 / Score: 0.98
# Step: 100354 / Episode: 18649 / Progress: Testing / Epsilon: 0 / Score: 0.99
# Step: 100355 / Episode: 18650 / Progress: Testing / Epsilon: 0 / Score: 1
# Step: 100360 / Episode: 18651 / Progress: Testing / Epsilon: 0 / Score: 0.96
# Step: 100364 / Episode: 18652 / Progress: Testing / Epsilon: 0 / Score: 0.97
# Step: 100365 / Episode: 18653 / Progress: Testing / Epsilon: 0 / Score: 1
# Step: 100366 / Episode: 18654 / Progress: Testing / Epsilon: 0 / Score: 1
# Step: 100369 / Episode: 18655 / Progress: Testing / Epsilon: 0 / Score: 0.98
# Step: 100373 / Episode: 18656 / Progress: Testing / Epsilon: 0 / Score: 0.97
# Step: 100376 / Episode: 18657 / Progress: Testing / Epsilon: 0 / Score: 0.98
# Step: 100381 / Episode: 18658 / Progress: Testing / Epsilon: 0 / Score: 0.96
# Step: 100386 / Episode: 18659 / Progress: Testing / Epsilon: 0 / Score: 0.96
# Step: 100389 / Episode: 18660 / Progress: Testing / Epsilon: 0 / Score: 0.98
# Step: 100393 / Episode: 18661 / Progress: Testing / Epsilon: 0 / Score: 0.97
# Step: 100394 / Episode: 18662 / Progress: Testing / Epsilon: 0 / Score: 1
# Step: 100398 / Episode: 18663 / Progress: Testing / Epsilon: 0 / Score: 0.97
# Step: 100402 / Episode: 18664 / Progress: Testing / Epsilon: 0 / Score: 0.97
# Step: 100404 / Episode: 18665 / Progress: Testing / Epsilon: 0 / Score: 0.99
# Step: 100407 / Episode: 18666 / Progress: Testing / Epsilon: 0 / Score: 0.98
# Step: 100408 / Episode: 18667 / Progress: Testing / Epsilon: 0 / Score: 1
# Step: 100409 / Episode: 18668 / Progress: Testing / Epsilon: 0 / Score: 1
# Step: 100412 / Episode: 18669 / Progress: Testing / Epsilon: 0 / Score: 0.98
# Step: 100415 / Episode: 18670 / Progress: Testing / Epsilon: 0 / Score: 0.98
# Step: 100420 / Episode: 18671 / Progress: Testing / Epsilon: 0 / Score: 0.96
# Step: 100425 / Episode: 18672 / Progress: Testing / Epsilon: 0 / Score: 0.96
# Step: 100426 / Episode: 18673 / Progress: Testing / Epsilon: 0 / Score: 1
# Step: 100429 / Episode: 18674 / Progress: Testing / Epsilon: 0 / Score: 0.98
# Step: 100432 / Episode: 18675 / Progress: Testing / Epsilon: 0 / Score: 0.98
# Step: 100435 / Episode: 18676 / Progress: Testing / Epsilon: 0 / Score: 0.98
# Step: 100440 / Episode: 18677 / Progress: Testing / Epsilon: 0 / Score: 0.96
# Step: 100441 / Episode: 18678 / Progress: Testing / Epsilon: 0 / Score: 1
# Step: 100444 / Episode: 18679 / Progress: Testing / Epsilon: 0 / Score: 0.98
# Step: 100445 / Episode: 18680 / Progress: Testing / Epsilon: 0 / Score: 1
# Step: 100448 / Episode: 18681 / Progress: Testing / Epsilon: 0 / Score: 0.98
# Step: 100451 / Episode: 18682 / Progress: Testing / Epsilon: 0 / Score: 0.98
# Step: 100455 / Episode: 18683 / Progress: Testing / Epsilon: 0 / Score: 0.97
# Step: 100458 / Episode: 18684 / Progress: Testing / Epsilon: 0 / Score: 0.98
# Step: 100459 / Episode: 18685 / Progress: Testing / Epsilon: 0 / Score: 1
# Step: 100460 / Episode: 18686 / Progress: Testing / Epsilon: 0 / Score: 1
# Step: 100464 / Episode: 18687 / Progress: Testing / Epsilon: 0 / Score: 0.97
# Step: 100468 / Episode: 18688 / Progress: Testing / Epsilon: 0 / Score: 0.97
# Step: 100470 / Episode: 18689 / Progress: Testing / Epsilon: 0 / Score: 0.99
# Step: 100473 / Episode: 18690 / Progress: Testing / Epsilon: 0 / Score: 0.98
# Step: 100476 / Episode: 18691 / Progress: Testing / Epsilon: 0 / Score: 0.98
# Step: 100477 / Episode: 18692 / Progress: Testing / Epsilon: 0 / Score: 1
# Step: 100478 / Episode: 18693 / Progress: Testing / Epsilon: 0 / Score: 1
# Step: 100480 / Episode: 18694 / Progress: Testing / Epsilon: 0 / Score: 0.99
# Step: 100482 / Episode: 18695 / Progress: Testing / Epsilon: 0 / Score: 0.99
# Step: 100484 / Episode: 18696 / Progress: Testing / Epsilon: 0 / Score: 0.99
# Step: 100487 / Episode: 18697 / Progress: Testing / Epsilon: 0 / Score: 0.98
# Step: 100491 / Episode: 18698 / Progress: Testing / Epsilon: 0 / Score: 0.97
# Step: 100493 / Episode: 18699 / Progress: Testing / Epsilon: 0 / Score: 0.99
# Step: 100495 / Episode: 18700 / Progress: Testing / Epsilon: 0 / Score: 0.99
# Step: 100498 / Episode: 18701 / Progress: Testing / Epsilon: 0 / Score: 0.98
# Step: 100504 / Episode: 18702 / Progress: Testing / Epsilon: 0 / Score: 0.95
# Step: 100507 / Episode: 18703 / Progress: Testing / Epsilon: 0 / Score: 0.98
# Step: 100510 / Episode: 18704 / Progress: Testing / Epsilon: 0 / Score: 0.98
# Step: 100513 / Episode: 18705 / Progress: Testing / Epsilon: 0 / Score: 0.98
# Step: 100516 / Episode: 18706 / Progress: Testing / Epsilon: 0 / Score: 0.98
# Step: 100518 / Episode: 18707 / Progress: Testing / Epsilon: 0 / Score: 0.99
# Step: 100519 / Episode: 18708 / Progress: Testing / Epsilon: 0 / Score: 1
# Step: 100521 / Episode: 18709 / Progress: Testing / Epsilon: 0 / Score: 0.99
# Step: 100524 / Episode: 18710 / Progress: Testing / Epsilon: 0 / Score: 0.98
# Step: 100529 / Episode: 18711 / Progress: Testing / Epsilon: 0 / Score: 0.96
# Step: 100534 / Episode: 18712 / Progress: Testing / Epsilon: 0 / Score: 0.96
# Step: 100540 / Episode: 18713 / Progress: Testing / Epsilon: 0 / Score: 0.95
# Step: 100542 / Episode: 18714 / Progress: Testing / Epsilon: 0 / Score: 0.99
# Step: 100546 / Episode: 18715 / Progress: Testing / Epsilon: 0 / Score: 0.97
# Step: 100551 / Episode: 18716 / Progress: Testing / Epsilon: 0 / Score: 0.96
# Step: 100553 / Episode: 18717 / Progress: Testing / Epsilon: 0 / Score: 0.99
# Step: 100555 / Episode: 18718 / Progress: Testing / Epsilon: 0 / Score: 0.99
# Step: 100557 / Episode: 18719 / Progress: Testing / Epsilon: 0 / Score: 0.99
# Step: 100558 / Episode: 18720 / Progress: Testing / Epsilon: 0 / Score: 1
# Step: 100559 / Episode: 18721 / Progress: Testing / Epsilon: 0 / Score: 1
# Step: 100561 / Episode: 18722 / Progress: Testing / Epsilon: 0 / Score: 0.99
# Step: 100564 / Episode: 18723 / Progress: Testing / Epsilon: 0 / Score: 0.98
# Step: 100567 / Episode: 18724 / Progress: Testing / Epsilon: 0 / Score: 0.98
# Step: 100569 / Episode: 18725 / Progress: Testing / Epsilon: 0 / Score: 0.99
# Step: 100572 / Episode: 18726 / Progress: Testing / Epsilon: 0 / Score: 0.98
# Step: 100574 / Episode: 18727 / Progress: Testing / Epsilon: 0 / Score: 0.99
# Step: 100577 / Episode: 18728 / Progress: Testing / Epsilon: 0 / Score: 0.98
# Step: 100579 / Episode: 18729 / Progress: Testing / Epsilon: 0 / Score: 0.99
# Step: 100581 / Episode: 18730 / Progress: Testing / Epsilon: 0 / Score: 0.99
# Step: 100582 / Episode: 18731 / Progress: Testing / Epsilon: 0 / Score: 1
# Step: 100585 / Episode: 18732 / Progress: Testing / Epsilon: 0 / Score: 0.98
# Step: 100588 / Episode: 18733 / Progress: Testing / Epsilon: 0 / Score: 0.98
# Step: 100590 / Episode: 18734 / Progress: Testing / Epsilon: 0 / Score: 0.99
# Step: 100591 / Episode: 18735 / Progress: Testing / Epsilon: 0 / Score: 1
# Step: 100594 / Episode: 18736 / Progress: Testing / Epsilon: 0 / Score: 0.98
# Step: 100598 / Episode: 18737 / Progress: Testing / Epsilon: 0 / Score: 0.97
# Step: 100600 / Episode: 18738 / Progress: Testing / Epsilon: 0 / Score: 0.99
# Step: 100605 / Episode: 18739 / Progress: Testing / Epsilon: 0 / Score: 0.96
# Step: 100609 / Episode: 18740 / Progress: Testing / Epsilon: 0 / Score: 0.97
# Step: 100612 / Episode: 18741 / Progress: Testing / Epsilon: 0 / Score: 0.98
# Step: 100614 / Episode: 18742 / Progress: Testing / Epsilon: 0 / Score: 0.99
# Step: 100617 / Episode: 18743 / Progress: Testing / Epsilon: 0 / Score: 0.98
# Step: 100619 / Episode: 18744 / Progress: Testing / Epsilon: 0 / Score: 0.99
# Step: 100621 / Episode: 18745 / Progress: Testing / Epsilon: 0 / Score: 0.99
# Step: 100623 / Episode: 18746 / Progress: Testing / Epsilon: 0 / Score: 0.99
# Step: 100625 / Episode: 18747 / Progress: Testing / Epsilon: 0 / Score: 0.99
# Step: 100627 / Episode: 18748 / Progress: Testing / Epsilon: 0 / Score: 0.99
# Step: 100630 / Episode: 18749 / Progress: Testing / Epsilon: 0 / Score: 0.98
# Step: 100632 / Episode: 18750 / Progress: Testing / Epsilon: 0 / Score: 0.99
# Step: 100634 / Episode: 18751 / Progress: Testing / Epsilon: 0 / Score: 0.99
# Step: 100639 / Episode: 18752 / Progress: Testing / Epsilon: 0 / Score: 0.96
# Step: 100640 / Episode: 18753 / Progress: Testing / Epsilon: 0 / Score: 1
# Step: 100645 / Episode: 18754 / Progress: Testing / Epsilon: 0 / Score: 0.96
# Step: 100646 / Episode: 18755 / Progress: Testing / Epsilon: 0 / Score: 1
# Step: 100650 / Episode: 18756 / Progress: Testing / Epsilon: 0 / Score: 0.97
# Step: 100654 / Episode: 18757 / Progress: Testing / Epsilon: 0 / Score: 0.97
# Step: 100656 / Episode: 18758 / Progress: Testing / Epsilon: 0 / Score: 0.99
# Step: 100661 / Episode: 18759 / Progress: Testing / Epsilon: 0 / Score: 0.96
# Step: 100663 / Episode: 18760 / Progress: Testing / Epsilon: 0 / Score: 0.99
# Step: 100664 / Episode: 18761 / Progress: Testing / Epsilon: 0 / Score: 1
# Step: 100668 / Episode: 18762 / Progress: Testing / Epsilon: 0 / Score: 0.97
# Step: 100673 / Episode: 18763 / Progress: Testing / Epsilon: 0 / Score: 0.96
# Step: 100676 / Episode: 18764 / Progress: Testing / Epsilon: 0 / Score: 0.98
# Step: 100678 / Episode: 18765 / Progress: Testing / Epsilon: 0 / Score: 0.99
# Step: 100683 / Episode: 18766 / Progress: Testing / Epsilon: 0 / Score: 0.96
# Step: 100685 / Episode: 18767 / Progress: Testing / Epsilon: 0 / Score: 0.99
# Step: 100692 / Episode: 18768 / Progress: Testing / Epsilon: 0 / Score: 0.94
# Step: 100696 / Episode: 18769 / Progress: Testing / Epsilon: 0 / Score: 0.97
# Step: 100698 / Episode: 18770 / Progress: Testing / Epsilon: 0 / Score: 0.99
# Step: 100700 / Episode: 18771 / Progress: Testing / Epsilon: 0 / Score: 0.99
# Step: 100703 / Episode: 18772 / Progress: Testing / Epsilon: 0 / Score: 0.98
# Step: 100706 / Episode: 18773 / Progress: Testing / Epsilon: 0 / Score: 0.98
# Step: 100709 / Episode: 18774 / Progress: Testing / Epsilon: 0 / Score: 0.98
# Step: 100710 / Episode: 18775 / Progress: Testing / Epsilon: 0 / Score: 1
# Step: 100713 / Episode: 18776 / Progress: Testing / Epsilon: 0 / Score: 0.98
# Step: 100718 / Episode: 18777 / Progress: Testing / Epsilon: 0 / Score: 0.96
# Step: 100724 / Episode: 18778 / Progress: Testing / Epsilon: 0 / Score: 0.95
# Step: 100727 / Episode: 18779 / Progress: Testing / Epsilon: 0 / Score: 0.98
# Step: 100731 / Episode: 18780 / Progress: Testing / Epsilon: 0 / Score: 0.97
# Step: 100733 / Episode: 18781 / Progress: Testing / Epsilon: 0 / Score: 0.99
# Step: 100737 / Episode: 18782 / Progress: Testing / Epsilon: 0 / Score: 0.97
# Step: 100740 / Episode: 18783 / Progress: Testing / Epsilon: 0 / Score: 0.98
# Step: 100742 / Episode: 18784 / Progress: Testing / Epsilon: 0 / Score: 0.99
# Step: 100746 / Episode: 18785 / Progress: Testing / Epsilon: 0 / Score: 0.97
# Step: 100748 / Episode: 18786 / Progress: Testing / Epsilon: 0 / Score: 0.99
# Step: 100753 / Episode: 18787 / Progress: Testing / Epsilon: 0 / Score: 0.96
# Step: 100758 / Episode: 18788 / Progress: Testing / Epsilon: 0 / Score: 0.96
# Step: 100760 / Episode: 18789 / Progress: Testing / Epsilon: 0 / Score: 0.99
# Step: 100761 / Episode: 18790 / Progress: Testing / Epsilon: 0 / Score: 1
# Step: 100763 / Episode: 18791 / Progress: Testing / Epsilon: 0 / Score: 0.99
# Step: 100764 / Episode: 18792 / Progress: Testing / Epsilon: 0 / Score: 1
# Step: 100765 / Episode: 18793 / Progress: Testing / Epsilon: 0 / Score: 1
# Step: 100768 / Episode: 18794 / Progress: Testing / Epsilon: 0 / Score: 0.98
# Step: 100772 / Episode: 18795 / Progress: Testing / Epsilon: 0 / Score: 0.97
# Step: 100776 / Episode: 18796 / Progress: Testing / Epsilon: 0 / Score: 0.97
# Step: 100778 / Episode: 18797 / Progress: Testing / Epsilon: 0 / Score: 0.99
# Step: 100780 / Episode: 18798 / Progress: Testing / Epsilon: 0 / Score: 0.99
# Step: 100783 / Episode: 18799 / Progress: Testing / Epsilon: 0 / Score: 0.98
# Step: 100788 / Episode: 18800 / Progress: Testing / Epsilon: 0 / Score: 0.96
# Step: 100790 / Episode: 18801 / Progress: Testing / Epsilon: 0 / Score: 0.99
# Step: 100791 / Episode: 18802 / Progress: Testing / Epsilon: 0 / Score: 1
# Step: 100796 / Episode: 18803 / Progress: Testing / Epsilon: 0 / Score: 0.96
# Step: 100800 / Episode: 18804 / Progress: Testing / Epsilon: 0 / Score: 0.97
# Step: 100802 / Episode: 18805 / Progress: Testing / Epsilon: 0 / Score: 0.99
# Step: 100805 / Episode: 18806 / Progress: Testing / Epsilon: 0 / Score: 0.98
# Step: 100808 / Episode: 18807 / Progress: Testing / Epsilon: 0 / Score: 0.98
# Step: 100811 / Episode: 18808 / Progress: Testing / Epsilon: 0 / Score: 0.98
# Step: 100812 / Episode: 18809 / Progress: Testing / Epsilon: 0 / Score: 1
# Step: 100815 / Episode: 18810 / Progress: Testing / Epsilon: 0 / Score: 0.98
# Step: 100817 / Episode: 18811 / Progress: Testing / Epsilon: 0 / Score: 0.99
# Step: 100818 / Episode: 18812 / Progress: Testing / Epsilon: 0 / Score: 1
# Step: 100819 / Episode: 18813 / Progress: Testing / Epsilon: 0 / Score: 1
# Step: 100820 / Episode: 18814 / Progress: Testing / Epsilon: 0 / Score: 1
# Step: 100823 / Episode: 18815 / Progress: Testing / Epsilon: 0 / Score: 0.98
# Step: 100825 / Episode: 18816 / Progress: Testing / Epsilon: 0 / Score: 0.99
# Step: 100827 / Episode: 18817 / Progress: Testing / Epsilon: 0 / Score: 0.99
# Step: 100829 / Episode: 18818 / Progress: Testing / Epsilon: 0 / Score: 0.99
# Step: 100830 / Episode: 18819 / Progress: Testing / Epsilon: 0 / Score: 1
# Step: 100835 / Episode: 18820 / Progress: Testing / Epsilon: 0 / Score: 0.96
# Step: 100836 / Episode: 18821 / Progress: Testing / Epsilon: 0 / Score: 1
# Step: 100839 / Episode: 18822 / Progress: Testing / Epsilon: 0 / Score: 0.98
# Step: 100840 / Episode: 18823 / Progress: Testing / Epsilon: 0 / Score: 1
# Step: 100844 / Episode: 18824 / Progress: Testing / Epsilon: 0 / Score: 0.97
# Step: 100846 / Episode: 18825 / Progress: Testing / Epsilon: 0 / Score: 0.99
# Step: 100847 / Episode: 18826 / Progress: Testing / Epsilon: 0 / Score: 1
# Step: 100852 / Episode: 18827 / Progress: Testing / Epsilon: 0 / Score: 0.96
# Step: 100853 / Episode: 18828 / Progress: Testing / Epsilon: 0 / Score: 1
# Step: 100856 / Episode: 18829 / Progress: Testing / Epsilon: 0 / Score: 0.98
# Step: 100859 / Episode: 18830 / Progress: Testing / Epsilon: 0 / Score: 0.98
# Step: 100861 / Episode: 18831 / Progress: Testing / Epsilon: 0 / Score: 0.99
# Step: 100864 / Episode: 18832 / Progress: Testing / Epsilon: 0 / Score: 0.98
# Step: 100867 / Episode: 18833 / Progress: Testing / Epsilon: 0 / Score: 0.98
# Step: 100870 / Episode: 18834 / Progress: Testing / Epsilon: 0 / Score: 0.98
# Step: 100872 / Episode: 18835 / Progress: Testing / Epsilon: 0 / Score: 0.99
# Step: 100873 / Episode: 18836 / Progress: Testing / Epsilon: 0 / Score: 1
# Step: 100874 / Episode: 18837 / Progress: Testing / Epsilon: 0 / Score: 1
# Step: 100878 / Episode: 18838 / Progress: Testing / Epsilon: 0 / Score: 0.97
# Step: 100880 / Episode: 18839 / Progress: Testing / Epsilon: 0 / Score: 0.99
# Step: 100884 / Episode: 18840 / Progress: Testing / Epsilon: 0 / Score: 0.97
# Step: 100885 / Episode: 18841 / Progress: Testing / Epsilon: 0 / Score: 1
# Step: 100889 / Episode: 18842 / Progress: Testing / Epsilon: 0 / Score: 0.97
# Step: 100890 / Episode: 18843 / Progress: Testing / Epsilon: 0 / Score: 1
# Step: 100891 / Episode: 18844 / Progress: Testing / Epsilon: 0 / Score: 1
# Step: 100896 / Episode: 18845 / Progress: Testing / Epsilon: 0 / Score: 0.96
# Step: 100898 / Episode: 18846 / Progress: Testing / Epsilon: 0 / Score: 0.99
# Step: 100899 / Episode: 18847 / Progress: Testing / Epsilon: 0 / Score: 1
# Step: 100901 / Episode: 18848 / Progress: Testing / Epsilon: 0 / Score: 0.99
# Step: 100902 / Episode: 18849 / Progress: Testing / Epsilon: 0 / Score: 1
# Step: 100907 / Episode: 18850 / Progress: Testing / Epsilon: 0 / Score: 0.96
# Step: 100911 / Episode: 18851 / Progress: Testing / Epsilon: 0 / Score: 0.97
# Step: 100913 / Episode: 18852 / Progress: Testing / Epsilon: 0 / Score: 0.99
# Step: 100917 / Episode: 18853 / Progress: Testing / Epsilon: 0 / Score: 0.97
# Step: 100921 / Episode: 18854 / Progress: Testing / Epsilon: 0 / Score: 0.97
# Step: 100925 / Episode: 18855 / Progress: Testing / Epsilon: 0 / Score: 0.97
# Step: 100927 / Episode: 18856 / Progress: Testing / Epsilon: 0 / Score: 0.99
# Step: 100930 / Episode: 18857 / Progress: Testing / Epsilon: 0 / Score: 0.98
# Step: 100932 / Episode: 18858 / Progress: Testing / Epsilon: 0 / Score: 0.99
# Step: 100936 / Episode: 18859 / Progress: Testing / Epsilon: 0 / Score: 0.97
# Step: 100938 / Episode: 18860 / Progress: Testing / Epsilon: 0 / Score: 0.99
# Step: 100941 / Episode: 18861 / Progress: Testing / Epsilon: 0 / Score: 0.98
# Step: 100942 / Episode: 18862 / Progress: Testing / Epsilon: 0 / Score: 1
# Step: 100946 / Episode: 18863 / Progress: Testing / Epsilon: 0 / Score: 0.97
# Step: 100951 / Episode: 18864 / Progress: Testing / Epsilon: 0 / Score: 0.96
# Step: 100952 / Episode: 18865 / Progress: Testing / Epsilon: 0 / Score: 1
# Step: 100956 / Episode: 18866 / Progress: Testing / Epsilon: 0 / Score: 0.97
# Step: 100960 / Episode: 18867 / Progress: Testing / Epsilon: 0 / Score: 0.97
# Step: 100962 / Episode: 18868 / Progress: Testing / Epsilon: 0 / Score: 0.99
# Step: 100965 / Episode: 18869 / Progress: Testing / Epsilon: 0 / Score: 0.98
# Step: 100968 / Episode: 18870 / Progress: Testing / Epsilon: 0 / Score: 0.98
# Step: 100971 / Episode: 18871 / Progress: Testing / Epsilon: 0 / Score: 0.98
# Step: 100973 / Episode: 18872 / Progress: Testing / Epsilon: 0 / Score: 0.99
# Step: 100976 / Episode: 18873 / Progress: Testing / Epsilon: 0 / Score: 0.98
# Step: 100980 / Episode: 18874 / Progress: Testing / Epsilon: 0 / Score: 0.97
# Step: 100981 / Episode: 18875 / Progress: Testing / Epsilon: 0 / Score: 1
# Step: 100982 / Episode: 18876 / Progress: Testing / Epsilon: 0 / Score: 1
# Step: 100984 / Episode: 18877 / Progress: Testing / Epsilon: 0 / Score: 0.99
# Step: 100985 / Episode: 18878 / Progress: Testing / Epsilon: 0 / Score: 1
# Step: 100989 / Episode: 18879 / Progress: Testing / Epsilon: 0 / Score: 0.97
# Step: 100994 / Episode: 18880 / Progress: Testing / Epsilon: 0 / Score: 0.96
# Step: 100995 / Episode: 18881 / Progress: Testing / Epsilon: 0 / Score: 1
# Step: 101001 / Episode: 18882 / Progress: Testing / Epsilon: 0 / Score: 0.95
# Finished
# Q_table 저장 완료!
